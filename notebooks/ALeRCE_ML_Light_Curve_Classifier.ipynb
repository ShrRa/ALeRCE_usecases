# %% [markdown]
# # ALeRCE light curve classifier
# Author: Ignacio Reyes, Last updated: 10/08/2021
# ### **Notebook under development**

# %% [markdown]
# ## Table of contents:
# * [Required libraries](#Required-libraries)
# * [The classifier](#The-classifier)
#     * [Brief explanation of the data](#Brief-explanation-of-the-data)
#     * [Model description](#Model-description)
#     * [Results](#Results)
#     * [ALeRCE Explorer](#ALeRCE-Explorer)
# * [Query model predictions](#Query-model-predictions)
#     * [Which objects have we found?](#Which-objects-have-we-found?)
# * [Spatial distribution of the predictions](#Spatial-distribution-of-the-predictions)
#     * [Galactic sources](#Galactic-sources-(LPV,-CEP,-YSO))
#     * [Extragalactic sources](#Extragalactic-sources-(QSO,-AGN,-Blazar,-SNe))
# * [Visualizing a sample of predicted objects](#Visualizing-a-sample-of-predicted-objects)

# %% [markdown]
# ## Required libraries

# %%
# !pip install alerce
# Out:
# Collecting alerce
#   Downloading alerce-1.0.1-py3-none-any.whl (9.5 kB)
# Requirement already satisfied: astropy>=4.0.1 in /home/alex/anaconda3/lib/python3.9/site-packages (from alerce) (4.3.1)
# Requirement already satisfied: requests>=2.24.0 in /home/alex/anaconda3/lib/python3.9/site-packages (from alerce) (2.26.0)
# Requirement already satisfied: pandas>=1.1.2 in /home/alex/anaconda3/lib/python3.9/site-packages (from alerce) (1.3.4)
# Requirement already satisfied: numpy>=1.17 in /home/alex/anaconda3/lib/python3.9/site-packages (from astropy>=4.0.1->alerce) (1.20.3)
# Requirement already satisfied: pyerfa>=1.7.3 in /home/alex/anaconda3/lib/python3.9/site-packages (from astropy>=4.0.1->alerce) (2.0.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/alex/anaconda3/lib/python3.9/site-packages (from pandas>=1.1.2->alerce) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /home/alex/anaconda3/lib/python3.9/site-packages (from pandas>=1.1.2->alerce) (2021.3)
# Requirement already satisfied: six>=1.5 in /home/alex/anaconda3/lib/python3.9/site-packages (from python-dateutil>=2.7.3->pandas>=1.1.2->alerce) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/alex/anaconda3/lib/python3.9/site-packages (from requests>=2.24.0->alerce) (1.26.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/alex/anaconda3/lib/python3.9/site-packages (from requests>=2.24.0->alerce) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/alex/anaconda3/lib/python3.9/site-packages (from requests>=2.24.0->alerce) (3.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/alex/anaconda3/lib/python3.9/site-packages (from requests>=2.24.0->alerce) (2021.10.8)
# Installing collected packages: alerce
# Successfully installed alerce-1.0.1

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:70% !important; }</style>"))
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from alerce.core import Alerce
import psycopg2
import json
# Out:
# <style>.container { width:70% !important; }</style>

# %% [markdown]
# # The classifier
# This notebook shows the light curve classifier from ALeRCE, described in detail in "Alert Classification for the ALeRCE Broker System: The Light Curve Classifier" by Sánchez-Sáez et. al (2020, under review). The goal of this notebook is to show how to access the predictions made by the model from ALeRCE's database. The code to replicate the results from the paper is contained in another GitHub repository.

# %% [markdown]
# ## Brief explanation of the data
# ALeRCE's database contains all the alerts generated by the Zwicky Transient Facility (ZTF) public stream. An alert is generated by ZTF each time an area of the sky is observed and a difference in brightness is detected. All alerts from the same coordinates are grouped into the same object with an object id (oid). Up to this date, the database contains more than 100 million alerts and 35 million objects.
#
# Most ZTF detections come from two filters, g and r. Let's see an example of a light curve from ZTF.

# %%
alerce_client = Alerce()

# %%
def plot_light_curve(df, title='', period=None):
    def colormap(i):
        if i == 1:
            return '#56e03a'
        elif i == 2:
            return '#d42f4b'
        else:
            return '#000000'
    for fid in [1, 2]:
        fid_df = df[df.fid == fid]
        if len(fid_df) == 0:
            continue
        if period is not None:
            mjd = (fid_df.mjd % period) / period
        else:
            mjd = fid_df.mjd
        plt.errorbar(
            mjd,
            fid_df.magpsf,
            yerr=fid_df.sigmapsf,
            fmt='*',
            c=colormap(fid))
    plt.gca().invert_yaxis()
    if period is not None:
        plt.xlabel(f'Phase (period={period:.3f})')
    else:
        plt.xlabel('Date [mjd]')
    plt.ylabel('Apparent magnitude [mag]')
    plt.title(title)

# %%
fig = plt.figure(figsize=(14, 10))
fig.patch.set_facecolor('white')
oid = 'ZTF20aaelulu'
light_curve = alerce_client.query_detections(oid, format='pandas')
plot_light_curve(light_curve, title=f'Light curve example {oid}')

# %% [markdown]
# The training set for the light curve classifier was built by cross matching ZTF with many astronomical catalogs with objects from known categories. The current training set of ALeRCE contains more than 1700 supernovae from many subclasses, almost 35k stochastic sources (QSO, AGN, Blazar, YSO, CV/Nova) and 87k light curves from periodic stars.

# %% [markdown]
# ## Model description
# When a light curve has more than 5 alerts in any of its bands it's classified by our light curve classifier. The model uses Machine Learning, combining feature extraction of the light curves and a model build of 4 Random Forest classifiers. Each object is classified in 15 astrophysical categories according to the following taxonomy.
#
# ![ALeRCE_taxonomy](colab/figures/ml/taxonomy.png)

# %% [markdown]
# Our classifier takes the light curve of an object, information about non-detections (previous ZTF observations where no alerts were generated), the metadata available from ZTF (e.g. coordinates) and cross match data from WISE if available. Using that data, more than 150 features are computed.
#
# Some of the computed features are:
# * Irregular autoregressive model from Eyheramendy et al. (2018).
# * Mexican hat power spectrum from Arévalo et al. (2012).
# * Parameters from a damped random walk model from Graham et al. (2017).
# * Structure function from Schmidt et al. (2010).
# * Multiband periodogram from Mondrik et al. (2015).

# %% [markdown]
# Once the features are computed they are classified by 4 Random Forest models, grouped in a hierarchy with two levels. The random forest on the top level classifies each object into 3 main categories: stochastic, transient and periodic sources. After that, each object is processed by 3 random forest classifiers in the bottom level, each one specialized in one category of objects.
#
# For example, the Transient Random Forest provides as output a vector with 4 probabilities, which corresponds to the probability of being a SN type Ia, SN type Ibc, SN type II or superluminous supernova.
#
# Finally, the outputs of the 4 classsifiers are combined using the total probabilities rule. That means that the probability of an object being a cepheid according to our classifier is the product of the object being a periodic star (computed by the random forest of the top level) and the probability of the object being a cepheid (computed by the periodic random forest).
#
# ![Hierarchical_Random_Forest](colab/figures/ml/hierarchical_rf.png)

# %% [markdown]
# ## Results
#
# The following confusion matrix is a summary of the performance of the model over the test set. This figure shows that the classifier is able to separate among the different classes. Of course some classes are difficult to distinguish, but the mistakes are "reasonable" in the sense that most of them choose a similar class. For example, most misclassified supernovae type Ia are labeled as another kind of supernova.
#
# The black boxes in the figure indicate the confusion inside of one of the three main categories: transient sources, periodic stars and stochastic objects.
# ![Confusion_matrix](colab/figures/ml/sanchez_paper_confusion_matrix.png)

# %% [markdown]
# ## ALeRCE Explorer
# All the data in ALeRCE's database, including model predictions, can be seen using the ALeRCE Explorer. The explorer is available in https://alerce.online
#
# This webpage is currently being updated, so the shown predictions can be out of date.
#
# ![ALeRCE_Explorer](colab/figures/ml/alerce_explorer.png)

# %% [markdown]
# Once an object is selected, all available information about it is shown. The figure in the bottom center shows the probabilities given by the light curve classifier.
#
# ![alerce_explorer_object](colab/figures/ml/alerce_explorer_object.png)

# %%
# !wget https://github.com/alercebroker/usecases/raw/master/alercereaduser_v4.json
# !mv alercereaduser_v4.json ..
credentials_file = "../alercereaduser_v4.json"
with open(credentials_file) as jsonfile:
    params = json.load(jsonfile)["params"]
conn = psycopg2.connect(
    dbname=params['dbname'], 
    user=params['user'], 
    host=params['host'], 
    password=params['password'])
# Out:
# --2022-05-06 14:44:12--  https://github.com/alercebroker/usecases/raw/master/alercereaduser_v4.json
# Resolving github.com (github.com)... 140.82.121.3
# Connecting to github.com (github.com)|140.82.121.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/alercebroker/usecases/master/alercereaduser_v4.json [following]
# --2022-05-06 14:44:12--  https://raw.githubusercontent.com/alercebroker/usecases/master/alercereaduser_v4.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.111.133, 185.199.108.133, 185.199.109.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.111.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 156 [text/plain]
# Saving to: ‘alercereaduser_v4.json’
#
# alercereaduser_v4.j 100%[===================>]     156  --.-KB/s    in 0s
#
# 2022-05-06 14:44:13 (6.33 MB/s) - ‘alercereaduser_v4.json’ saved [156/156]

# %%
query = "SELECT tablename FROM pg_tables"
tabs = pd.read_sql_query(query, conn)
str(list(tabs['tablename']))
# Out:
# "['outlier', 'feature_version', 'gaia_ztf', 'ps1_ztf', 'ss_ztf', 'allwise', 'xmatch', 'taxonomy', 'pg_statistic', 'pg_type', 'feature', 'step', 'pg_foreign_table', 'pg_authid', 'non_detection', 'detection', 'magstat', 'pg_statistic_ext_data', 'lc_classifier', 'reference', 'pipeline', 'pg_largeobject', 'dataquality', 'pg_user_mapping', 'pg_subscription', 'pg_attribute', 'pg_proc', 'pg_class', 'pg_attrdef', 'pg_constraint', 'pg_inherits', 'pg_index', 'pg_operator', 'pg_opfamily', 'pg_opclass', 'pg_am', 'pg_amop', 'pg_amproc', 'pg_language', 'pg_largeobject_metadata', 'pg_aggregate', 'pg_statistic_ext', 'pg_rewrite', 'pg_trigger', 'pg_event_trigger', 'pg_description', 'pg_cast', 'pg_enum', 'pg_namespace', 'pg_conversion', 'pg_depend', 'pg_database', 'pg_db_role_setting', 'pg_tablespace', 'pg_auth_members', 'pg_shdepend', 'pg_shdescription', 'pg_ts_config', 'pg_ts_config_map', 'pg_ts_dict', 'pg_ts_parser', 'pg_ts_template', 'pg_extension', 'pg_foreign_data_wrapper', 'pg_foreign_server', 'pg_policy', 'pg_replication_origin', 'pg_default_acl', 'pg_init_privs', 'pg_seclabel', 'pg_shseclabel', 'pg_collation', 'pg_partitioned_table', 'pg_range', 'pg_transform', 'pg_sequence', 'pg_publication', 'pg_publication_rel', 'pg_subscription_rel', 'sql_implementation_info', 'sql_parts', 'sql_sizing', 'sql_features', 'object', 'lc_classifier_stochastic', 'lc_classifier_top', 'lc_classifier_periodic', 'lc_classifier_transient', 'probability', 'stamp_classifier']"

# %%
query = "SELECT * FROM probability WHERE oid = 'ZTF19aargvet'"
tabs = pd.read_sql_query(query, conn)
tabs[tabs['probability']>0.5]
# Out:
#              oid           classifier_name      classifier_version class_name  \
# 6   ZTF19aargvet             lc_classifier   hierarchical_rf_1.1.0        LPV
# 18  ZTF19aargvet    lc_classifier_periodic   hierarchical_rf_1.1.0        LPV
# 25  ZTF19aargvet  lc_classifier_stochastic   hierarchical_rf_1.1.0        YSO
# 26  ZTF19aargvet         lc_classifier_top   hierarchical_rf_1.1.0   Periodic
# 37  ZTF19aargvet          stamp_classifier  stamp_classifier_1.0.0         VS
# 42  ZTF19aargvet          stamp_classifier  stamp_classifier_1.0.4         VS
#
#     probability  ranking
# 6      0.976140        1
# 18     0.986000        1
# 25     0.848000        1
# 26     0.990000        1
# 37     0.815075        1
# 42     0.575152        1

# %%
oid = 'ZTF19aargvet'

query = f"select oid, name, value from feature where name = 'Multiband_period' and oid = '{oid}';"
period_df = pd.read_sql_query(query, conn)
if len(period_df) > 0:
    period = float(period_df.value.values[0])

    
fig = plt.figure(figsize=(14, 10))
fig.patch.set_facecolor('white')
light_curve = alerce_client.query_detections(oid, format='pandas')
plot_light_curve(light_curve, title=f'{astro_class} candidate {oid}', period=period)

# %%
# Heavy query (~ 2 min)
query = "select * from probability where classifier_name = 'lc_classifier' and ranking = 1;"
bhrf_predictions = pd.read_sql_query(query, conn)
bhrf_predictions
# Out:
#                   oid classifier_name     classifier_version      class_name  \
# 0        ZTF18aadcbyv   lc_classifier  hierarchical_rf_1.1.0             YSO
# 1        ZTF20acrcfon   lc_classifier  hierarchical_rf_1.1.0             RRL
# 2        ZTF18acceerh   lc_classifier  hierarchical_rf_1.1.0  Periodic-Other
# 3        ZTF19acuynqw   lc_classifier  hierarchical_rf_1.1.0  Periodic-Other
# 4        ZTF18abgqdub   lc_classifier  hierarchical_rf_1.1.0             LPV
# ...               ...             ...                    ...             ...
# 1689376  ZTF18aczbnfk   lc_classifier  hierarchical_rf_1.1.0             LPV
# 1689377  ZTF18aacwdmo   lc_classifier  hierarchical_rf_1.1.0            DSCT
# 1689378  ZTF18abtivdo   lc_classifier  hierarchical_rf_1.1.0  Periodic-Other
# 1689379  ZTF18aacwdda   lc_classifier  hierarchical_rf_1.1.0             YSO
# 1689380  ZTF18aacwclb   lc_classifier  hierarchical_rf_1.1.0             YSO
#
#          probability  ranking
# 0           0.389424        1
# 1           0.212352        1
# 2           0.489532        1
# 3           0.633840        1
# 4           0.938432        1
# ...              ...      ...
# 1689376     0.809508        1
# 1689377     0.325080        1
# 1689378     0.648024        1
# 1689379     0.292752        1
# 1689380     0.199836        1
#
# [1689381 rows x 6 columns]

# %% [markdown]
# # Query model predictions
# ## Which objects have we found?

# %%
pred_classes_count = bhrf_predictions.groupby('class_name').count()['oid']
pred_classes_count = pred_classes_count.sort_values(ascending=False)
fig = plt.figure(figsize=(14, 10))
fig.patch.set_facecolor('white')
plt.bar(pred_classes_count.index.values, pred_classes_count.values)
plt.gca().set_yscale('log')
plt.title('Predicted class frequency')
# Out:
# Text(0.5, 1.0, 'Predicted class frequency')

# %% [markdown]
# ## Spatial distribution of the predictions
# ### Galactic sources (LPV, CEP, YSO)

# %%
galactic_sources = bhrf_predictions[bhrf_predictions['class_name'].isin(
    ['LPV', 'CEP', 'YSO'])]
galactic_sources
# Out:
#                   oid classifier_name     classifier_version class_name  \
# 0        ZTF18aadcbyv   lc_classifier  hierarchical_rf_1.1.0        YSO
# 4        ZTF18abgqdub   lc_classifier  hierarchical_rf_1.1.0        LPV
# 5        ZTF18aaztgsd   lc_classifier  hierarchical_rf_1.1.0        LPV
# 7        ZTF18abcswqt   lc_classifier  hierarchical_rf_1.1.0        LPV
# 10       ZTF19abuawie   lc_classifier  hierarchical_rf_1.1.0        LPV
# ...               ...             ...                    ...        ...
# 1689369  ZTF18abdlbbd   lc_classifier  hierarchical_rf_1.1.0        LPV
# 1689371  ZTF17aacpxez   lc_classifier  hierarchical_rf_1.1.0        YSO
# 1689376  ZTF18aczbnfk   lc_classifier  hierarchical_rf_1.1.0        LPV
# 1689379  ZTF18aacwdda   lc_classifier  hierarchical_rf_1.1.0        YSO
# 1689380  ZTF18aacwclb   lc_classifier  hierarchical_rf_1.1.0        YSO
#
#          probability  ranking
# 0           0.389424        1
# 4           0.938432        1
# 5           0.503424        1
# 7           0.301016        1
# 10          0.635712        1
# ...              ...      ...
# 1689369     0.829080        1
# 1689371     0.640332        1
# 1689376     0.809508        1
# 1689379     0.292752        1
# 1689380     0.199836        1
#
# [537193 rows x 6 columns]

# %%
# Heavy query (~ 8 min)
query = "select oid, name, value from feature where name = 'gal_l' or name = 'gal_b';"
features = pd.read_sql_query(query, conn)
features
# Out:
#                   oid   name      value
# 0        ZTF19aargwjd  gal_b   4.166084
# 1        ZTF19aargwjd  gal_l   9.798493
# 2        ZTF20abmctuf  gal_b -18.397648
# 3        ZTF20abmctuf  gal_l  86.174409
# 4        ZTF18abgsptz  gal_b   1.409847
# ...               ...    ...        ...
# 3378659  ZTF18abxznqs  gal_b  -7.628971
# 3378660  ZTF18abxznqs  gal_l  81.512862
# 3378661  ZTF18acriibt  gal_b  -7.699532
# 3378662  ZTF18acriibt  gal_l  81.668100
# 3378663  ZTF18adlalli  gal_l  66.422617
#
# [3378664 rows x 3 columns]

# %%
gal_l = features[features.name == 'gal_l'].copy()
gal_l.rename(columns={'value': 'gal_l'}, inplace=True)
gal_l.drop(columns=['name'], inplace=True)
gal_l.set_index('oid', inplace=True)

gal_b = features[features.name == 'gal_b'].copy()
gal_b.rename(columns={'value': 'gal_b'}, inplace=True)
gal_b.drop(columns=['name'], inplace=True)
gal_b.set_index('oid', inplace=True)

coordinates = pd.concat([gal_l, gal_b], sort=True, axis=1)
coordinates
# Out:
#                    gal_l      gal_b
# oid
# ZTF17aaaaaal  150.836443  -2.113660
# ZTF17aaaaaam  151.324448  -2.308580
# ZTF17aaaaaan  156.195091  -3.562309
# ZTF17aaaaaao  156.135700  -3.847893
# ZTF17aaaaaas  155.698153   0.933241
# ...                  ...        ...
# ZTF22aaikatd  113.252767  -3.684679
# ZTF22aaikave   99.038002 -17.785965
# ZTF22aaikbfm  109.889461  -9.358383
# ZTF22aaikbgl  117.568345  -3.932785
# ZTF22aaikbqf  106.901119 -16.009454
#
# [1689332 rows x 2 columns]

# %%
n_per_class = 1000  # sample size
replace = False  # with replacement
fn = lambda obj: obj.loc[np.random.choice(obj.index, n_per_class, replace),:]
galactic_sources_subset = galactic_sources.groupby('class_name', as_index=False).apply(fn)
galactic_sources_subset = galactic_sources_subset.droplevel(level=0)
galactic_sources_subset
# Out:
#                   oid classifier_name     classifier_version class_name  \
# 1001485  ZTF18aaakipm   lc_classifier  hierarchical_rf_1.1.0        CEP
# 594555   ZTF18abyroch   lc_classifier  hierarchical_rf_1.1.0        CEP
# 362334   ZTF18abfguxl   lc_classifier  hierarchical_rf_1.1.0        CEP
# 276247   ZTF18aayvbil   lc_classifier  hierarchical_rf_1.1.0        CEP
# 1436644  ZTF19acenndk   lc_classifier  hierarchical_rf_1.1.0        CEP
# ...               ...             ...                    ...        ...
# 1026461  ZTF18aawcefj   lc_classifier  hierarchical_rf_1.1.0        YSO
# 817388   ZTF18acvvrct   lc_classifier  hierarchical_rf_1.1.0        YSO
# 464205   ZTF18abaqwjs   lc_classifier  hierarchical_rf_1.1.0        YSO
# 16927    ZTF18acsodoq   lc_classifier  hierarchical_rf_1.1.0        YSO
# 1423270  ZTF19abyegzt   lc_classifier  hierarchical_rf_1.1.0        YSO
#
#          probability  ranking
# 1001485     0.244080        1
# 594555      0.467360        1
# 362334      0.269192        1
# 276247      0.927144        1
# 1436644     0.214928        1
# ...              ...      ...
# 1026461     0.354220        1
# 817388      0.509184        1
# 464205      0.265016        1
# 16927       0.199240        1
# 1423270     0.310104        1
#
# [3000 rows x 6 columns]

# %%
coordinates_subset = coordinates.loc[galactic_sources_subset.oid]
fig = plt.figure(figsize=(14, 10))
fig.patch.set_facecolor('white')
plt.scatter(
    coordinates_subset.values[:, 0],
    coordinates_subset.values[:, 1],
    alpha=0.2,
    s=galactic_sources_subset.probability*100
)
plt.xlabel('Galactic latitude [deg]')
plt.ylabel('Galactic longitude [deg]')
plt.title('Spatial distribution of predictions: LPV, CEP, YSO')
# Out:
# Text(0.5, 1.0, 'Spatial distribution of predictions: LPV, CEP, YSO')

# %% [markdown]
# ### Extragalactic sources (QSO, AGN, Blazar, SNe)

# %%
extragalactic_sources = bhrf_predictions[bhrf_predictions['class_name'].isin(
    ['QSO', 'Blazar', 'SNIa', 'SNII', 'AGN', 'SNIbc', 'SLSN'])]
extragalactic_sources
# Out:
#                   oid classifier_name     classifier_version class_name  \
# 9        ZTF19aaaicqh   lc_classifier  hierarchical_rf_1.1.0     Blazar
# 12       ZTF20acvafso   lc_classifier  hierarchical_rf_1.1.0     Blazar
# 13       ZTF22aacicie   lc_classifier  hierarchical_rf_1.1.0        QSO
# 35       ZTF18aadcjyj   lc_classifier  hierarchical_rf_1.1.0        QSO
# 36       ZTF18aadckcy   lc_classifier  hierarchical_rf_1.1.0        QSO
# ...               ...             ...                    ...        ...
# 1689281  ZTF18aadbual   lc_classifier  hierarchical_rf_1.1.0        QSO
# 1689300  ZTF21abasoli   lc_classifier  hierarchical_rf_1.1.0        QSO
# 1689315  ZTF19aawfkgw   lc_classifier  hierarchical_rf_1.1.0        QSO
# 1689331  ZTF20acmghao   lc_classifier  hierarchical_rf_1.1.0        QSO
# 1689367  ZTF20aagvolr   lc_classifier  hierarchical_rf_1.1.0        QSO
#
#          probability  ranking
# 9           0.466528        1
# 12          0.201312        1
# 13          0.736032        1
# 35          0.790400        1
# 36          0.607376        1
# ...              ...      ...
# 1689281     0.584672        1
# 1689300     0.757248        1
# 1689315     0.534772        1
# 1689331     0.618488        1
# 1689367     0.656684        1
#
# [163633 rows x 6 columns]

# %%
n_per_class = 100  # sample size
replace = False  # with replacement
fn = lambda obj: obj.loc[np.random.choice(obj.index, n_per_class, replace),:]
extragalactic_sources_subset = extragalactic_sources.groupby('class_name', as_index=False).apply(fn)
extragalactic_sources_subset = extragalactic_sources_subset.droplevel(level=0)
extragalactic_sources_subset
# Out:
#                   oid classifier_name     classifier_version class_name  \
# 1342794  ZTF19aasctre   lc_classifier  hierarchical_rf_1.1.0        AGN
# 910162   ZTF19aaddgkz   lc_classifier  hierarchical_rf_1.1.0        AGN
# 363169   ZTF18aarchxv   lc_classifier  hierarchical_rf_1.1.0        AGN
# 1392889  ZTF19abegjnv   lc_classifier  hierarchical_rf_1.1.0        AGN
# 1342209  ZTF21abdvbmm   lc_classifier  hierarchical_rf_1.1.0        AGN
# ...               ...             ...                    ...        ...
# 440056   ZTF21aagzfso   lc_classifier  hierarchical_rf_1.1.0      SNIbc
# 1475277  ZTF20aaflaug   lc_classifier  hierarchical_rf_1.1.0      SNIbc
# 1524881  ZTF20abqdqyh   lc_classifier  hierarchical_rf_1.1.0      SNIbc
# 468289   ZTF18aavghvh   lc_classifier  hierarchical_rf_1.1.0      SNIbc
# 1574647  ZTF21aatnpwb   lc_classifier  hierarchical_rf_1.1.0      SNIbc
#
#          probability  ranking
# 1342794     0.701520        1
# 910162      0.171704        1
# 363169      0.818064        1
# 1392889     0.678832        1
# 1342209     0.243000        1
# ...              ...      ...
# 440056      0.147920        1
# 1475277     0.486000        1
# 1524881     0.374680        1
# 468289      0.385440        1
# 1574647     0.273672        1
#
# [700 rows x 6 columns]

# %%
coordinates_subset = coordinates.loc[extragalactic_sources_subset.oid]
fig = plt.figure(figsize=(14, 10))
fig.patch.set_facecolor('white')
plt.scatter(
    coordinates_subset.values[:, 0],
    coordinates_subset.values[:, 1],
    alpha=0.4,
    s=extragalactic_sources_subset.probability*100
)
plt.xlabel('Galactic latitude [deg]')
plt.ylabel('Galactic longitude [deg]')
plt.title('Spatial distribution of extragalactic pred. sources')
# Out:
# Text(0.5, 1.0, 'Spatial distribution of extragalactic pred. sources')

# %% [markdown]
# ## Visualizing a sample of predicted objects

# %%
n_per_class = 1  # sample size
minimum_probability = 0.3
replace = False  # with replacement
fn = lambda obj: obj.loc[np.random.choice(obj.index, n_per_class, replace),:]
filtered_bhrf_predictions = bhrf_predictions[bhrf_predictions.probability >= minimum_probability]
sample_per_class = filtered_bhrf_predictions.groupby('class_name', as_index=False).apply(fn)
sample_per_class = sample_per_class.droplevel(level=0)
sample_per_class
# Out:
#                   oid classifier_name     classifier_version      class_name  \
# 112551   ZTF21acapnyc   lc_classifier  hierarchical_rf_1.1.0             AGN
# 300527   ZTF20aacxhjv   lc_classifier  hierarchical_rf_1.1.0          Blazar
# 1653498  ZTF18abfclgy   lc_classifier  hierarchical_rf_1.1.0             CEP
# 90224    ZTF18aagpyca   lc_classifier  hierarchical_rf_1.1.0         CV/Nova
# 755402   ZTF18acsjmcb   lc_classifier  hierarchical_rf_1.1.0            DSCT
# 994989   ZTF17aabwolv   lc_classifier  hierarchical_rf_1.1.0               E
# 1137921  ZTF18ablqzxb   lc_classifier  hierarchical_rf_1.1.0             LPV
# 346174   ZTF18acuwsqq   lc_classifier  hierarchical_rf_1.1.0  Periodic-Other
# 725616   ZTF18acqtefr   lc_classifier  hierarchical_rf_1.1.0             QSO
# 831956   ZTF18acwyjrj   lc_classifier  hierarchical_rf_1.1.0             RRL
# 819296   ZTF18acvwkvc   lc_classifier  hierarchical_rf_1.1.0            SLSN
# 1365513  ZTF19aaxdjdi   lc_classifier  hierarchical_rf_1.1.0            SNII
# 1504296  ZTF20aaykndv   lc_classifier  hierarchical_rf_1.1.0            SNIa
# 1452228  ZTF19acslqnc   lc_classifier  hierarchical_rf_1.1.0           SNIbc
# 879628   ZTF18adbjmev   lc_classifier  hierarchical_rf_1.1.0             YSO
#
#          probability  ranking
# 112551      0.530460        1
# 300527      0.467364        1
# 1653498     0.334476        1
# 90224       0.482160        1
# 755402      0.601032        1
# 994989      0.768000        1
# 1137921     0.698896        1
# 346174      0.558108        1
# 725616      0.413280        1
# 831956      0.938000        1
# 819296      0.332112        1
# 1365513     0.383656        1
# 1504296     0.463072        1
# 1452228     0.475048        1
# 879628      0.451008        1

# %%
fig = plt.figure(figsize=(14, 25))
fig.patch.set_facecolor('white')
for index in range(len(sample_per_class)):
    astro_class = sample_per_class['class_name'].values[index]
    oid = sample_per_class['oid'].values[index]
    light_curve = alerce_client.query_detections(oid, format='pandas')
    plt.subplot(8, 2, index+1)
    period = None
    if astro_class in ['CEP', 'E', 'DSCT', 'LPV', 'Periodic-Other', 'RRL']:
        query = f"select oid, name, value from feature where name = 'Multiband_period' and oid = '{oid}';"
        period_df = pd.read_sql_query(query, conn)
        if len(period_df) > 0:
            period = float(period_df.value.values[0])
    plot_light_curve(light_curve, title=f'{astro_class} candidate {oid}', period=period)
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_45877/1607821806.py in <module>
#       5     oid = sample_per_class['oid'].values[index]
#       6     light_curve = alerce_client.query_detections(oid, format='pandas')
# ----> 7     plt.subplot(8, 2, index+1)
#       8     period = None
#       9     if astro_class in ['CEP', 'E', 'DSCT', 'LPV', 'Periodic-Other', 'RRL']:
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1270
#    1271     # First, search for an existing subplot with a matching spec.
# -> 1272     key = SubplotSpec._from_subplot_args(fig, args)
#    1273
#    1274     for ax in fig.axes:
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/gridspec.py in _from_subplot_args(figure, args)
#     651                     num = int(num)
#     652                 if num < 1 or num > rows*cols:
# --> 653                     raise ValueError(
#     654                         f"num must be 1 <= num <= {rows*cols}, not {num}")
#     655                 i = j = num
#
# ValueError: num must be 1 <= num <= 16, not 17

# %%
class_name='CEP'
perOther=bhrf_predictions[bhrf_predictions['class_name']==class_name]

# %%
perOther[perOther['probability']>0.5]
# Out:
#                   oid classifier_name     classifier_version class_name  \
# 1735     ZTF18aazgeih   lc_classifier  hierarchical_rf_1.1.0        CEP
# 2705     ZTF18aawbnkn   lc_classifier  hierarchical_rf_1.1.0        CEP
# 2888     ZTF18aborpjm   lc_classifier  hierarchical_rf_1.1.0        CEP
# 3077     ZTF18abaqyce   lc_classifier  hierarchical_rf_1.1.0        CEP
# 4354     ZTF18aayedtk   lc_classifier  hierarchical_rf_1.1.0        CEP
# ...               ...             ...                    ...        ...
# 1685870  ZTF17aaafzcp   lc_classifier  hierarchical_rf_1.1.0        CEP
# 1687350  ZTF18aasnlmo   lc_classifier  hierarchical_rf_1.1.0        CEP
# 1687938  ZTF18abkcphu   lc_classifier  hierarchical_rf_1.1.0        CEP
# 1688634  ZTF17aaassax   lc_classifier  hierarchical_rf_1.1.0        CEP
# 1688770  ZTF18abdkdqk   lc_classifier  hierarchical_rf_1.1.0        CEP
#
#          probability  ranking
# 1735        0.580860        1
# 2705        0.666540        1
# 2888        0.790224        1
# 3077        0.586976        1
# 4354        0.556780        1
# ...              ...      ...
# 1685870     0.569088        1
# 1687350     0.817072        1
# 1687938     0.551232        1
# 1688634     0.747296        1
# 1688770     0.535360        1
#
# [3420 rows x 6 columns]

# %%
n_per_class = 10000  # shistple size
minimum_probability = 0.6
maximum_probability=1
replace = False  # without replacement
fn = lambda obj: obj.loc[np.random.choice(obj.index, n_per_class, replace),:]
filtered_perOther = perOther[(perOther.probability >= minimum_probability) & (perOther.probability <= maximum_probability)]
sample_per_class = filtered_perOther.groupby('class_name', as_index=False).apply(fn)

sample_per_class = sample_per_class.droplevel(level=0)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_45877/2343165076.py in <module>
#       5 fn = lambda obj: obj.loc[np.random.choice(obj.index, n_per_class, replace),:]
#       6 filtered_perOther = perOther[(perOther.probability >= minimum_probability) & (perOther.probability <= maximum_probability)]
# ----> 7 sample_per_class = filtered_perOther.groupby('class_name', as_index=False).apply(fn)
#       8 sample_per_class = sample_per_class.droplevel(level=0)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in apply(self, func, *args, **kwargs)
#    1273         with option_context("mode.chained_assignment", None):
#    1274             try:
# -> 1275                 result = self._python_apply_general(f, self._selected_obj)
#    1276             except TypeError:
#    1277                 # gh-20949
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/groupby.py in _python_apply_general(self, f, data)
#    1307             data after applying f
#    1308         """
# -> 1309         keys, values, mutated = self.grouper.apply(f, data, self.axis)
#    1310
#    1311         return self._wrap_applied_output(
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/ops.py in apply(self, f, data, axis)
#     802             try:
#     803                 sdata = splitter.sorted_data
# --> 804                 result_values, mutated = splitter.fast_apply(f, sdata, group_keys)
#     805
#     806             except IndexError:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/groupby/ops.py in fast_apply(self, f, sdata, names)
#    1347         # must return keys::list, values::list, mutated::bool
#    1348         starts, ends = lib.generate_slices(self.slabels, self.ngroups)
# -> 1349         return libreduction.apply_frame_axis0(sdata, f, names, starts, ends)
#    1350
#    1351     def _chop(self, sdata: DataFrame, slice_obj: slice) -> DataFrame:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/reduction.pyx in pandas._libs.reduction.apply_frame_axis0()
#
# /tmp/ipykernel_45877/2343165076.py in <lambda>(obj)
#       3 maximum_probability=1
#       4 replace = False  # without replacement
# ----> 5 fn = lambda obj: obj.loc[np.random.choice(obj.index, n_per_class, replace),:]
#       6 filtered_perOther = perOther[(perOther.probability >= minimum_probability) & (perOther.probability <= maximum_probability)]
#       7 sample_per_class = filtered_perOther.groupby('class_name', as_index=False).apply(fn)
#
# mtrand.pyx in numpy.random.mtrand.RandomState.choice()
#
# ValueError: Cannot take a larger sample than population when 'replace=False'

# %%
fig = plt.figure(figsize=(14, 25))
fig.patch.set_facecolor('white')
for index in range(len(sample_per_class)):
    astro_class = sample_per_class['class_name'].values[index]
    oid = sample_per_class['oid'].values[index]
    light_curve = alerce_client.query_detections(oid, format='pandas')
    plt.subplot(8, 2, index+1)
    period = None
    if astro_class ==class_name:
        query = f"select oid, name, value from feature where name = 'Multiband_period' and oid = '{oid}';"
        period_df = pd.read_sql_query(query, conn)
        if len(period_df) > 0:
            period = float(period_df.value.values[0])
    plot_light_curve(light_curve, title=f'{astro_class} candidate {oid}', period=period)
plt.tight_layout()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_45877/3900663913.py in <module>
#       5     oid = sample_per_class['oid'].values[index]
#       6     light_curve = alerce_client.query_detections(oid, format='pandas')
# ----> 7     plt.subplot(8, 2, index+1)
#       8     period = None
#       9     if astro_class ==class_name:
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py in subplot(*args, **kwargs)
#    1270
#    1271     # First, search for an existing subplot with a matching spec.
# -> 1272     key = SubplotSpec._from_subplot_args(fig, args)
#    1273
#    1274     for ax in fig.axes:
#
# ~/anaconda3/lib/python3.9/site-packages/matplotlib/gridspec.py in _from_subplot_args(figure, args)
#     651                     num = int(num)
#     652                 if num < 1 or num > rows*cols:
# --> 653                     raise ValueError(
#     654                         f"num must be 1 <= num <= {rows*cols}, not {num}")
#     655                 i = j = num
#
# ValueError: num must be 1 <= num <= 16, not 17

# %%
# %%time
lc=alerce_client.query_lightcurve(oid)
# Out:
# CPU times: user 12.4 ms, sys: 0 ns, total: 12.4 ms
# Wall time: 605 ms

# %%
# %%time
for index in range(len(sample_per_class)):
    oid = sample_per_class['oid'].values[index]
    light_curve = alerce_client.query_detections(oid, format='pandas')
# Out:
# CPU times: user 1.47 s, sys: 0 ns, total: 1.47 s
# Wall time: 1min 6s

# %%
sample_per_class['oid'].values(6)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_45877/623760596.py in <module>
# ----> 1 sample_per_class['oid'].values(6)
#
# TypeError: 'numpy.ndarray' object is not callable

# %%
light_curve = alerce_client.query_detections(oid='', format='pandas')
